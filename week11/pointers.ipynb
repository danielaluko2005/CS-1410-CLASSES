# %% [markdown]
# `Pointers` are variables that hold the memory adress of variables.

# %% [markdown]
# `How to use a pointer to a CLASS`--> ` Point* point1 = new Point;` -->The `new` is used to create a pointer.
#
# In order to `call` the class using the pointer,
#
# `Point* point2 = new Point(16, 8);`
#
# `point2->Print()`

# %% [markdown]
# The `delete operator` deallocates (or frees) a block of memory that was allocated with the new operator. The statement delete pointerVariable; deallocates a memory block pointed to by pointerVariable. If pointerVariable is null, delete has no effect.
#
# `How it is Used:`
#
#
# int main() {
#
#    Point* point1 = new Point(73, 19);
#
#    cout << "X = " << point1->X << endl;
#
#    cout << "Y = " << point1->Y << endl;
#
#    delete point1;
#
#    // Error: can't use point1 after deletion
#
#    point1->Print();
#
# }

# %% [markdown]
# `The delete operator deallocates memory that point1 points to but does not set point1 to null.`

# %% [markdown]
# int main() {
#
#    // Allocate points
#
#    int pointCount = 4;
#
#    Point* manyPoints = new Point[pointCount];
#
#    // Display each point
#
#    for (int i = 0; i < pointCount; ++i)
#
#       manyPoints[i].Print();
#
#    // Free all points with one delete
#
#    delete[] manyPoints;
#
#    return 0
#
# }

# %% [markdown]
# #include <iostream>
# using namespace std;
#
# class Deer {
#    public:
#       Deer();
#       void Print();
#
#       int age;
#       int weight;
# };
# Deer::Deer() {
#    age = 0;
#    weight = 0;
# }
# void Deer::Print() {
#    cout << "Deer's age: " << age << endl;
#    cout << "Deer's weight: " << weight <<  endl;
# }
#
# int main() {
#    int ageValue;
#    int weightValue;
#
#    /* Additional variable declarations go here */
#    Deer* myDeer=new Deer();
#    //  Point* sample = new Point;
#
#    cin >> ageValue;
#    cin >> weightValue;
#
#    /* Your code goes here */
#    myDeer->age=ageValue;
#    myDeer->weight=weightValue;
#
#    myDeer->Print();
#
#    return 0;
# }
#
# `Instead of myDeer.age because it's a pointer it is myDeer->age.`
# `However if it is a member Pointer(myMovingBodies=new MovingBody[count]; then for each index of the meber function use the dot(myMovingBodies[i].Read();)`
#
# `Example of member function::-`
# #include <iostream>
# using namespace std;
#
# class MovingBody {
#    public:
#       MovingBody();
#       void Read();
#       void Print();
#       ~MovingBody();
#    private:
#       int velocity;
#       int duration;
# };
# MovingBody::MovingBody() {
#    velocity = 0;
#    duration = 0;
# }
# void MovingBody::Read() {
#    cin >> velocity;
#    cin >> duration;
# }
# void MovingBody::Print() {
#    cout << "MovingBody's velocity: " << velocity << endl;
#    cout << "MovingBody's duration: " << duration << endl;
# }
# MovingBody::~MovingBody() { // Covered in section on Destructors.
#    cout << "MovingBody with velocity " << velocity << " and duration " << duration << " is deallocated." <<  endl;
# }
#
# int main() {
#    MovingBody* myMovingBodies = nullptr;
#    int count;
#    int i;
#
#    /* Your code goes here */
#    cin>>count;
#    myMovingBodies=new MovingBody[count];
#    for (int i=0; i<count;i++){
#          myMovingBodies[i].Read();
#          myMovingBodies[i].Print();
#    }
#
#    delete[] myMovingBodies;
#
#    return 0;
# }
